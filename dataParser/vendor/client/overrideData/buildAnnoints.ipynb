# %%
import json
import logging
import os

import pandas as pd

# %% [markdown]
# ### Globals

# %%
LANG_CODES_TO_NAMES = {
    "en": "English",
    "ru": "Russian",
    "ko": "Korean",
    "cmn-Hant": "Traditional Chinese",
    "ja": "Japanese",
    "de": "German",
    "es": "Spanish",
}
logger = logging.getLogger(__name__)

# %% [markdown]
# ### Helper functions

# %%
# Function to get the script directory
def get_script_dir():
    """Returns the directory where the script is located."""
    dir = os.getcwd()
    if dir.endswith("overrideData"):
        return dir[:-len("overrideData")]
    return dir

# Function to generate file path
def get_file_path(base_dir: str, file: str, lang: str, is_en=False):
    return f"{base_dir}{lang if not is_en else 'en'}/{file}.json"

# Function to load a JSON file
def load_file(base_dir: str, file: str, lang: str, is_en=False):
    path = get_file_path(base_dir, file, lang, is_en)
    logger.info(f"LOADING FILE: ++ {path}")
    with open(path, encoding="utf-8") as f:
        return json.load(f)

# Function to load a DataFrame
def load_df(base_dir: str, file: str, lang: str, is_en=False):
    path = get_file_path(base_dir, file, lang, is_en)
    logger.info(f"LOADING FILE: ++ {path}")
    return pd.read_json(path, encoding="utf-8")

# %% [markdown]
# ### Setting more globals

# %%
cwd = get_script_dir()
base_dir = cwd + "/tables/"
out_file = cwd + "/overrideData/annoints.json"
lang = "en"

# %% [markdown]
# Load all tables needed for annoints

# %%
blight_results = load_df(base_dir, "BlightCraftingResults", lang)
blight_items = load_df(base_dir, "BlightCraftingItems", lang)
blight_crafting_recipes = load_df(base_dir, "BlightCraftingRecipes", lang).drop(columns=["_index", "Id"])
passive_skills = load_df(base_dir, "PassiveSkills", lang).drop(columns=["_index"])
len(blight_results), len(blight_items), len(blight_crafting_recipes), len(passive_skills)
# Out:
# (1000, 10, 1000, 6189)

# %% [markdown]
# Join results and skills on r.passiveskill = p.passiveskillgraphid

# %%
joined_results_skills = pd.merge(
    blight_results,
    passive_skills,
    left_on='PassiveSkill',
    right_index=True,
    suffixes=('_results', '_skills')
)[["PassiveSkillGraphId", "Name"]]
joined_results_skills
# Out:
#      PassiveSkillGraphId                  Name
# 0                   9736      Insulated Treads
# 2                  42354        Blinding Flash
# 4                  46565        Stance Breaker
# 6                  59636             Open Mind
# 8                  30456            High Alert
# ..                   ...                   ...
# 994                 7809            Wild Storm
# 995                62439        Enraged Reaver
# 996                44566         Lightning Rod
# 998                62034           Prism Guard
# 999                 4547  Unnatural Resilience
#
# [603 rows x 2 columns]

# %%
blight_crafting_recipes.head()
# Out:
#    BlightCraftingResult BlightCraftingItems
# 0                     0           [0, 0, 0]
# 1                     1           [0, 0, 1]
# 2                     2           [0, 1, 0]
# 3                     3           [1, 0, 0]
# 4                     4           [0, 1, 1]

# %%
joined_results_crafting = pd.merge(
    blight_crafting_recipes,
    joined_results_skills,
    left_on='BlightCraftingResult',
    right_index=True,
    suffixes=('_results', '_crafting')
)[["PassiveSkillGraphId","BlightCraftingItems","Name"]]
joined_results_crafting
# Out:
#      PassiveSkillGraphId BlightCraftingItems                  Name
# 0                   9736           [0, 0, 0]      Insulated Treads
# 2                  42354           [0, 1, 0]        Blinding Flash
# 4                  46565           [0, 1, 1]        Stance Breaker
# 6                  59636           [1, 1, 0]             Open Mind
# 8                  30456           [0, 0, 2]            High Alert
# ..                   ...                 ...                   ...
# 994                 7809           [9, 7, 9]            Wild Storm
# 995                62439           [9, 9, 7]        Enraged Reaver
# 996                44566           [8, 9, 9]         Lightning Rod
# 998                62034           [9, 9, 8]           Prism Guard
# 999                 4547           [9, 9, 9]  Unnatural Resilience
#
# [603 rows x 3 columns]

# %% [markdown]
# Get Emotion tiers into the lists now

# %%
def get_tiers(crafting_items, blight_items):
    """
    Aggregates the 'Tier' from blight_items for each item ID in crafting_items.
    It assumes blight_items is indexed by item IDs.
    """
    return [blight_items.loc[item_id, 'Tier'] for item_id in crafting_items]

# Apply the function to each row in 'joined_results_crafting'
joined_results_crafting['BlightCraftingItems'] = joined_results_crafting.apply(
    lambda row: get_tiers(row['BlightCraftingItems'], blight_items), axis=1
)
joined_results_crafting
# Out:
#      PassiveSkillGraphId BlightCraftingItems                  Name
# 0                   9736           [1, 1, 1]      Insulated Treads
# 2                  42354           [1, 2, 1]        Blinding Flash
# 4                  46565           [1, 2, 2]        Stance Breaker
# 6                  59636           [2, 2, 1]             Open Mind
# 8                  30456           [1, 1, 3]            High Alert
# ..                   ...                 ...                   ...
# 994                 7809         [10, 8, 10]            Wild Storm
# 995                62439         [10, 10, 8]        Enraged Reaver
# 996                44566         [9, 10, 10]         Lightning Rod
# 998                62034         [10, 10, 9]           Prism Guard
# 999                 4547        [10, 10, 10]  Unnatural Resilience
#
# [603 rows x 3 columns]

# %% [markdown]
# ## Load json data now
#
# This is correct now, but we need to load in the items from the api side of it now

# %%
raw_json_data = {
    group['id']: group
    for group 
    in json.loads(
            open(
                f"{cwd}/../json-api/{lang}/stats.json", encoding="utf-8"
            ).read()
        )['result']
    }

# %% [markdown]
# get the enchants json data

# %%
enchants = raw_json_data["enchant"]
enchants_entries = enchants["entries"]
enchants_entries_filtered = [entry for entry in enchants_entries if entry["id"].startswith("enchant.stat_2954116742")]
enchants_df = pd.DataFrame(enchants_entries_filtered)
enchants_df
# Out:
#                                 id                            text     type
# 0    enchant.stat_2954116742|30456            Allocates High Alert  enchant
# 1    enchant.stat_2954116742|57190             Allocates Doomsayer  enchant
# 2    enchant.stat_2954116742|34300  Allocates Conservative Casting  enchant
# 3    enchant.stat_2954116742|57388   Allocates Overwhelming Strike  enchant
# 4    enchant.stat_2954116742|50609          Allocates Hard to Kill  enchant
# ..                             ...                             ...      ...
# 598  enchant.stat_2954116742|44527  Allocates Cautious Concoctions  enchant
# 599  enchant.stat_2954116742|47635              Allocates Overload  enchant
# 600  enchant.stat_2954116742|30392               Allocates Succour  enchant
# 601   enchant.stat_2954116742|4547  Allocates Unnatural Resilience  enchant
# 602   enchant.stat_2954116742|2113      Allocates Martial Artistry  enchant
#
# [603 rows x 3 columns]

# %%
enchants_df["value"] = enchants_df["id"].apply(lambda x: x.split("|")[-1]).astype(int)
enchants_df
# Out:
#                                 id                            text     type  \
# 0    enchant.stat_2954116742|30456            Allocates High Alert  enchant
# 1    enchant.stat_2954116742|57190             Allocates Doomsayer  enchant
# 2    enchant.stat_2954116742|34300  Allocates Conservative Casting  enchant
# 3    enchant.stat_2954116742|57388   Allocates Overwhelming Strike  enchant
# 4    enchant.stat_2954116742|50609          Allocates Hard to Kill  enchant
# ..                             ...                             ...      ...
# 598  enchant.stat_2954116742|44527  Allocates Cautious Concoctions  enchant
# 599  enchant.stat_2954116742|47635              Allocates Overload  enchant
# 600  enchant.stat_2954116742|30392               Allocates Succour  enchant
# 601   enchant.stat_2954116742|4547  Allocates Unnatural Resilience  enchant
# 602   enchant.stat_2954116742|2113      Allocates Martial Artistry  enchant
#
#      value
# 0    30456
# 1    57190
# 2    34300
# 3    57388
# 4    50609
# ..     ...
# 598  44527
# 599  47635
# 600  30392
# 601   4547
# 602   2113
#
# [603 rows x 4 columns]

# %% [markdown]
# ## Join enchants_df with results_crafting

# %%
output_df = pd.merge(
    joined_results_crafting,
    enchants_df,
    left_on='PassiveSkillGraphId',
    right_on='value',
    suffixes=('_results', '_json')
)[["BlightCraftingItems","Name","text","value"]].sort_values(by="value")
output_df
# Out:
#     BlightCraftingItems                  Name                            text  \
# 462          [4, 3, 10]    Fast Acting Toxins    Allocates Fast Acting Toxins
# 260           [2, 6, 8]        Insightfulness        Allocates Insightfulness
# 430           [5, 9, 9]           Storm Swell           Allocates Storm Swell
# 124           [6, 6, 3]          Heatproofing          Allocates Heatproofing
# 335           [3, 9, 4]      Natural Immunity      Allocates Natural Immunity
# ..                  ...                   ...                             ...
# 153           [7, 4, 2]               Titanic               Allocates Titanic
# 101           [6, 3, 4]           Viciousness           Allocates Viciousness
# 478          [10, 5, 3]     Overflowing Power     Allocates Overflowing Power
# 50            [2, 5, 3]        Smooth Buckler        Allocates Smooth Buckler
# 576          [9, 7, 10]  Repeating Explosives  Allocates Repeating Explosives
#
#      value
# 462     55
# 260    116
# 430    336
# 124    372
# 335    934
# ..     ...
# 153  65160
# 101  65193
# 478  65204
# 50   65265
# 576  65468
#
# [603 rows x 4 columns]

# %% [markdown]
# # form into output json

# %%
starting_json = {
    "ref": "Allocates #",
    "better": 0,
    "trade": {
      "ids": {
        "enchant": [
          "enchant.stat_2954116742"
        ]
      },
      "option": True
    }
}
starting_json
# Out:
# {'ref': 'Allocates #',
#  'better': 0,
#  'trade': {'ids': {'enchant': ['enchant.stat_2954116742']}, 'option': True}}

# %%
def row_to_json(row):
    return {
        "string": row["text"],
        "value": row["value"],
        "oils": ",".join(map(str, row["BlightCraftingItems"])),
    }

# %%
matchers = output_df.apply(lambda row: row_to_json(row), axis=1).to_list()
starting_json["matchers"] = matchers

starting_json
# Out:
# {'ref': 'Allocates #',
#  'better': 0,
#  'trade': {'ids': {'enchant': ['enchant.stat_2954116742']}, 'option': True},
#  'matchers': [{'string': 'Allocates Fast Acting Toxins',
#    'value': 55,
#    'oils': '4,3,10'},
#   {'string': 'Allocates Insightfulness', 'value': 116, 'oils': '2,6,8'},
#   {'string': 'Allocates Storm Swell', 'value': 336, 'oils': '5,9,9'},
#   {'string': 'Allocates Heatproofing', 'value': 372, 'oils': '6,6,3'},
#   {'string': 'Allocates Natural Immunity', 'value': 934, 'oils': '3,9,4'},
#   {'string': 'Allocates Shockwaves', 'value': 1087, 'oils': '3,4,1'},
#   {'string': 'Allocates Lust for Power', 'value': 1104, 'oils': '10,2,2'},
#   {'string': 'Allocates Urgent Call', 'value': 1169, 'oils': '8,10,9'},
#   {'string': 'Allocates Unbending', 'value': 1352, 'oils': '8,7,4'},
#   {'string': 'Allocates Spiral into Depression',
#    'value': 1546,
#    'oils': '5,7,9'},
#   {'string': 'Allocates Illuminated Crown', 'value': 1823, 'oils': '9,4,9'},
#   {'string': 'Allocates Wellspring', 'value': 2021, 'oils': '6,3,2'},
#   {'string': 'Allocates Martial Artistry', 'value': 2113, 'oils': '10,1,8'},
#   {'string': 'Allocates Spiral into Insanity',
#    'value': 2138,
#    'oils': '3,10,5'},
#   {'string': 'Allocates Pure Energy', 'value': 2254, 'oils': '8,2,6'},
#   {'string': 'Allocates Turn the Clock Forward',
#    'value': 2335,
#    'oils': '7,8,2'},
#   {'string': 'Allocates Blade Flurry', 'value': 2394, 'oils': '5,5,7'},
#   {'string': 'Allocates Stars Aligned', 'value': 2486, 'oils': '9,5,10'},
#   {'string': 'Allocates Sundering', 'value': 2511, 'oils': '6,4,1'},
#   {'string': 'Allocates Ancestral Alacrity', 'value': 2575, 'oils': '9,4,2'},
#   {'string': 'Allocates Skullcrusher', 'value': 2645, 'oils': '1,10,1'},
#   {'string': 'Allocates Perpetual Freeze', 'value': 2863, 'oils': '2,1,10'},
#   {'string': 'Allocates Final Barrage', 'value': 2999, 'oils': '10,7,6'},
#   {'string': 'Allocates Revenge', 'value': 3188, 'oils': '1,6,10'},
#   {'string': 'Allocates Melding', 'value': 3215, 'oils': '2,5,9'},
#   {'string': 'Allocates Void', 'value': 3492, 'oils': '10,1,6'},
#   {'string': 'Allocates Raw Mana', 'value': 3567, 'oils': '9,1,10'},
#   {'string': 'Allocates Dynamism', 'value': 3688, 'oils': '10,3,1'},
#   {'string': 'Allocates Spike Pit', 'value': 3698, 'oils': '10,10,3'},
#   {'string': 'Allocates Path of Winter', 'value': 3823, 'oils': '9,5,7'},
#   {'string': 'Allocates Eldritch Will', 'value': 3894, 'oils': '10,2,10'},
#   {'string': 'Allocates Fate Finding', 'value': 3921, 'oils': '8,7,3'},
#   {'string': 'Allocates Forces of Nature', 'value': 3985, 'oils': '9,10,1'},
#   {'string': 'Allocates Icebreaker', 'value': 4031, 'oils': '1,4,8'},
#   {'string': 'Allocates Versatile Arms', 'value': 4238, 'oils': '1,10,5'},
#   {'string': 'Allocates Adverse Growth', 'value': 4295, 'oils': '1,4,6'},
#   {'string': 'Allocates Coated Knife', 'value': 4423, 'oils': '1,7,9'},
#   {'string': 'Allocates Pinned Down', 'value': 4447, 'oils': '6,7,5'},
#   {'string': 'Allocates Piercing Shot', 'value': 4534, 'oils': '6,2,6'},
#   {'string': 'Allocates Unnatural Resilience',
#    'value': 4547,
#    'oils': '10,10,10'},
#   {'string': 'Allocates Climate Change', 'value': 4627, 'oils': '3,10,7'},
#   {'string': 'Allocates Hulking Smash', 'value': 4673, 'oils': '6,2,2'},
#   {'string': 'Allocates Near Sighted', 'value': 4709, 'oils': '1,5,4'},
#   {'string': 'Allocates Afterimage', 'value': 4716, 'oils': '2,3,6'},
#   {'string': 'Allocates Dependable Ward', 'value': 4931, 'oils': '1,8,5'},
#   {'string': 'Allocates Heavy Frost', 'value': 4959, 'oils': '7,8,4'},
#   {'string': 'Allocates Flip the Script', 'value': 4985, 'oils': '1,6,1'},
#   {'string': 'Allocates Seeing Stars', 'value': 5009, 'oils': '1,2,4'},
#   {'string': 'Allocates Escape Strategy', 'value': 5227, 'oils': '7,4,7'},
#   {'string': 'Allocates Echoing Frost', 'value': 5257, 'oils': '9,2,3'},
#   {'string': 'Allocates Shredding Force', 'value': 5284, 'oils': '2,10,3'},
#   {'string': 'Allocates Critical Overload', 'value': 5501, 'oils': '2,5,1'},
#   {'string': 'Allocates Watchtowers', 'value': 5580, 'oils': '6,9,9'},
#   {'string': 'Allocates Endurance', 'value': 5663, 'oils': '2,10,5'},
#   {'string': 'Allocates Echoing Thunder', 'value': 5703, 'oils': '7,9,1'},
#   {'string': 'Allocates Brutal', 'value': 5710, 'oils': '7,7,5'},
#   {'string': 'Allocates Ancient Aegis', 'value': 5728, 'oils': '7,4,5'},
#   {'string': 'Allocates Deadly Swarm', 'value': 5777, 'oils': '4,7,6'},
#   {'string': 'Allocates Stand and Deliver', 'value': 5802, 'oils': '6,3,10'},
#   {'string': 'Allocates Core of the Guardian', 'value': 6133, 'oils': '4,3,8'},
#   {'string': 'Allocates Power Shots', 'value': 6178, 'oils': '4,10,9'},
#   {'string': 'Allocates Push the Advantage', 'value': 6229, 'oils': '8,1,6'},
#   {'string': 'Allocates Stand Ground', 'value': 6304, 'oils': '3,4,2'},
#   {'string': 'Allocates Cacophony', 'value': 6514, 'oils': '10,2,8'},
#   {'string': 'Allocates Burning Strikes', 'value': 6544, 'oils': '5,6,10'},
#   {'string': 'Allocates Aggravation', 'value': 6655, 'oils': '7,9,5'},
#   {'string': 'Allocates Relentless Vindicator',
#    'value': 6898,
#    'oils': '5,4,5'},
#   {'string': 'Allocates Reusable Ammunition', 'value': 7062, 'oils': '4,10,7'},
#   {'string': 'Allocates Stimulants', 'value': 7163, 'oils': '7,3,3'},
#   {'string': 'Allocates Echoing Pulse', 'value': 7302, 'oils': '8,5,1'},
#   {'string': 'Allocates Ignore Pain', 'value': 7341, 'oils': '7,8,9'},
#   {'string': 'Allocates Life from Death', 'value': 7344, 'oils': '3,3,3'},
#   {'string': 'Allocates Retaliation', 'value': 7395, 'oils': '1,8,9'},
#   {'string': 'Allocates Rapid Strike', 'value': 7604, 'oils': '1,8,8'},
#   {'string': 'Allocates Pierce the Heart', 'value': 7651, 'oils': '7,10,4'},
#   {'string': 'Allocates Internal Bleeding', 'value': 7668, 'oils': '2,7,4'},
#   {'string': 'Allocates Relentless', 'value': 7721, 'oils': '7,7,3'},
#   {'string': 'Allocates Breaking Point', 'value': 7777, 'oils': '8,4,8'},
#   {'string': 'Allocates Wild Storm', 'value': 7809, 'oils': '10,8,10'},
#   {'string': 'Allocates Endless Circuit', 'value': 8273, 'oils': '10,7,7'},
#   {'string': 'Allocates Ruin', 'value': 8483, 'oils': '3,7,9'},
#   {'string': 'Allocates Leaping Ambush', 'value': 8531, 'oils': '7,2,2'},
#   {'string': 'Allocates Spiked Whip', 'value': 8535, 'oils': '6,5,4'},
#   {'string': 'Allocates Burning Nature', 'value': 8554, 'oils': '3,10,3'},
#   {'string': 'Allocates Reverberation', 'value': 8660, 'oils': '4,2,8'},
#   {'string': 'Allocates Sturdy Ally', 'value': 8791, 'oils': '8,3,7'},
#   {'string': 'Allocates Multitasking', 'value': 8810, 'oils': '4,6,8'},
#   {'string': 'Allocates Fast Metabolism', 'value': 8827, 'oils': '9,10,9'},
#   {'string': 'Allocates Tempered Mind', 'value': 8831, 'oils': '10,7,4'},
#   {'string': 'Allocates Unforgiving', 'value': 8881, 'oils': '10,3,3'},
#   {'string': 'Allocates Death from Afar', 'value': 8904, 'oils': '10,8,2'},
#   {'string': 'Allocates Right Hand of Darkness',
#    'value': 8957,
#    'oils': '5,10,9'},
#   {'string': 'Allocates Giantslayer', 'value': 9020, 'oils': '7,10,7'},
#   {'string': 'Allocates Escalation', 'value': 9187, 'oils': '10,3,2'},
#   {'string': 'Allocates Mental Perseverance', 'value': 9226, 'oils': '1,6,3'},
#   {'string': 'Allocates Swift Skewering', 'value': 9227, 'oils': '8,1,3'},
#   {'string': 'Allocates Snowpiercer', 'value': 9421, 'oils': '10,2,6'},
#   {'string': 'Allocates One with the Storm', 'value': 9444, 'oils': '10,9,6'},
#   {'string': 'Allocates Catapult', 'value': 9472, 'oils': '5,6,2'},
#   {'string': 'Allocates Dampening Shield', 'value': 9642, 'oils': '2,8,10'},
#   {'string': 'Allocates Insulated Treads', 'value': 9736, 'oils': '1,1,1'},
#   {'string': 'Allocates Price of Freedom', 'value': 9908, 'oils': '5,8,1'},
#   {'string': 'Allocates Feel the Earth', 'value': 9968, 'oils': '4,9,6'},
#   {'string': 'Allocates Repulsion', 'value': 10029, 'oils': '6,4,7'},
#   {'string': 'Allocates Combat Alchemy', 'value': 10053, 'oils': '2,3,1'},
#   {'string': 'Allocates Javelin', 'value': 10265, 'oils': '3,7,6'},
#   {'string': 'Allocates Overzealous', 'value': 10295, 'oils': '8,7,10'},
#   {'string': 'Allocates Sudden Escalation', 'value': 10398, 'oils': '6,4,8'},
#   {'string': 'Allocates Exposed to the Inferno',
#    'value': 10423,
#    'oils': '10,5,6'},
#   {'string': 'Allocates Reaving', 'value': 10602, 'oils': '7,1,5'},
#   {'string': 'Allocates Offensive Stance', 'value': 10681, 'oils': '6,8,10'},
#   {'string': 'Allocates Bloodthirsty', 'value': 10772, 'oils': '6,6,8'},
#   {'string': 'Allocates Bestial Rage', 'value': 10873, 'oils': '1,6,8'},
#   {'string': 'Allocates Strong Chin', 'value': 10998, 'oils': '4,1,2'},
#   {'string': 'Allocates Volatile Catalyst', 'value': 11037, 'oils': '3,2,1'},
#   {'string': 'Allocates Whirling Onslaught', 'value': 11178, 'oils': '10,1,4'},
#   {'string': 'Allocates Volcanic Skin', 'value': 11366, 'oils': '9,10,4'},
#   {'string': 'Allocates Necrotic Touch', 'value': 11376, 'oils': '7,7,9'},
#   {'string': 'Allocates Sniper', 'value': 11526, 'oils': '10,9,7'},
#   {'string': 'Allocates Spreading Shocks', 'value': 11578, 'oils': '2,6,6'},
#   {'string': 'Allocates Heavy Ammunition', 'value': 11826, 'oils': '2,3,3'},
#   {'string': 'Allocates Dreamcatcher', 'value': 11838, 'oils': '6,9,8'},
#   {'string': 'Allocates Flash Storm', 'value': 12337, 'oils': '4,1,10'},
#   {'string': 'Allocates Harness the Elements',
#    'value': 12611,
#    'oils': '6,6,10'},
#   {'string': 'Allocates Asceticism', 'value': 12661, 'oils': '10,1,2'},
#   {'string': 'Allocates Vale Shelter', 'value': 12750, 'oils': '3,6,7'},
#   {'string': 'Allocates Warm the Heart', 'value': 12998, 'oils': '1,9,8'},
#   {'string': 'Allocates Radial Force', 'value': 13233, 'oils': '4,3,1'},
#   {'string': 'Allocates Heartbreaking', 'value': 13407, 'oils': '10,4,8'},
#   {'string': 'Allocates Shadow Dancing', 'value': 13457, 'oils': '7,2,7'},
#   {'string': 'Allocates Resilient Soul', 'value': 13505, 'oils': '5,2,5'},
#   {'string': 'Allocates Loose Flesh', 'value': 13542, 'oils': '1,8,3'},
#   {'string': 'Allocates Curved Weapon', 'value': 13708, 'oils': '3,8,3'},
#   {'string': 'Allocates Deadly Force', 'value': 13724, 'oils': '6,9,5'},
#   {'string': 'Allocates Lightning Quick', 'value': 13738, 'oils': '8,8,10'},
#   {'string': 'Allocates Controlling Magic', 'value': 13823, 'oils': '5,8,10'},
#   {'string': 'Allocates Precise Point', 'value': 13895, 'oils': '2,5,7'},
#   {'string': 'Allocates Split the Earth', 'value': 13980, 'oils': '10,4,6'},
#   {'string': 'Allocates Arcane Blossom', 'value': 14324, 'oils': '5,7,7'},
#   {'string': 'Allocates Deterioration', 'value': 14343, 'oils': '4,4,10'},
#   {'string': 'Allocates Suffusion', 'value': 14383, 'oils': '8,7,2'},
#   {'string': 'Allocates Bravado', 'value': 14777, 'oils': '9,2,7'},
#   {'string': 'Allocates Spiral into Mania', 'value': 14934, 'oils': '1,5,9'},
#   {'string': 'Allocates Growing Swarm', 'value': 14945, 'oils': '2,4,8'},
#   {'string': 'Allocates Break Focus', 'value': 15051, 'oils': '4,5,1'},
#   {'string': 'Allocates Power Conduction', 'value': 15083, 'oils': '2,9,9'},
#   {'string': 'Allocates Hale Heart', 'value': 15374, 'oils': '7,4,3'},
#   {'string': 'Allocates Heavy Drinker', 'value': 15617, 'oils': '5,5,5'},
#   {'string': 'Allocates Shedding Skin', 'value': 15644, 'oils': '5,1,4'},
#   {'string': 'Allocates Siphon', 'value': 15829, 'oils': '4,5,2'},
#   {'string': 'Allocates Building Toxins', 'value': 15986, 'oils': '3,10,10'},
#   {'string': 'Allocates Ether Flow', 'value': 16256, 'oils': '5,3,5'},
#   {'string': 'Allocates Mental Alacrity', 'value': 16466, 'oils': '8,5,4'},
#   {'string': 'Allocates Lingering Whispers', 'value': 16499, 'oils': '10,7,5'},
#   {'string': 'Allocates Jack of all Trades', 'value': 16618, 'oils': '3,8,5'},
#   {'string': 'Allocates Impact Area', 'value': 16626, 'oils': '4,5,6'},
#   {'string': 'Allocates Pinpoint Shot', 'value': 16816, 'oils': '10,5,5'},
#   {'string': 'Allocates Blade Catcher', 'value': 17029, 'oils': '8,5,2'},
#   {'string': "Allocates General's Bindings", 'value': 17150, 'oils': '4,8,5'},
#   {'string': 'Allocates Silent Guardian', 'value': 17229, 'oils': '8,3,6'},
#   {'string': 'Allocates Spell Haste', 'value': 17254, 'oils': '1,2,10'},
#   {'string': 'Allocates Tough Claw', 'value': 17260, 'oils': '3,1,7'},
#   {'string': 'Allocates Perforation', 'value': 17330, 'oils': '3,3,9'},
#   {'string': 'Allocates Adrenaline Rush', 'value': 17340, 'oils': '6,1,8'},
#   {'string': 'Allocates Reaching Strike', 'value': 17372, 'oils': '10,4,2'},
#   {'string': 'Allocates Moment of Truth', 'value': 17548, 'oils': '1,9,6'},
#   {'string': 'Allocates Resourceful Ally', 'value': 17600, 'oils': '1,3,9'},
#   {'string': 'Allocates Vengeance', 'value': 17762, 'oils': '2,8,5'},
#   {'string': 'Allocates Escape Velocity', 'value': 17854, 'oils': '3,6,9'},
#   {'string': 'Allocates Volatile Grenades', 'value': 17882, 'oils': '4,1,7'},
#   {'string': 'Allocates Careful Consideration',
#    'value': 17955,
#    'oils': '4,4,3'},
#   {'string': 'Allocates Rapid Recharge', 'value': 17973, 'oils': '2,1,6'},
#   {'string': 'Allocates Breath of Ice', 'value': 18086, 'oils': '9,6,9'},
#   {'string': 'Allocates Bleeding Out', 'value': 18308, 'oils': '7,9,8'},
#   {'string': 'Allocates Savoured Blood', 'value': 18397, 'oils': '7,1,1'},
#   {'string': 'Allocates Ancestral Mending', 'value': 18419, 'oils': '5,8,4'},
#   {'string': 'Allocates Cruel Fate', 'value': 18465, 'oils': '5,3,7'},
#   {'string': 'Allocates Lasting Trauma', 'value': 18496, 'oils': '9,4,5'},
#   {'string': 'Allocates Crushing Verdict', 'value': 18505, 'oils': '5,9,1'},
#   {'string': 'Allocates Arcane Intensity', 'value': 19044, 'oils': '6,8,7'},
#   {'string': 'Allocates Eagle Eye', 'value': 19104, 'oils': '1,3,2'},
#   {'string': 'Allocates Potent Incantation', 'value': 19125, 'oils': '4,4,6'},
#   {'string': 'Allocates Immaterial', 'value': 19156, 'oils': '1,6,5'},
#   {'string': 'Allocates Projectile Bulwark', 'value': 19236, 'oils': '1,8,7'},
#   {'string': 'Allocates Supportive Ancestors',
#    'value': 19249,
#    'oils': '8,6,10'},
#   {'string': 'Allocates Prolonged Assault', 'value': 19442, 'oils': '2,7,9'},
#   {'string': 'Allocates Left Hand of Darkness',
#    'value': 19644,
#    'oils': '10,9,5'},
#   {'string': 'Allocates Cremation', 'value': 19715, 'oils': '10,6,10'},
#   {'string': 'Allocates Thin Ice', 'value': 19722, 'oils': '9,1,3'},
#   {'string': 'Allocates Endless Blizzard', 'value': 19955, 'oils': '10,9,8'},
#   {'string': 'Allocates Erraticism', 'value': 20032, 'oils': '7,3,2'},
#   {'string': 'Allocates No Escape', 'value': 20165, 'oils': '3,6,6'},
#   {'string': 'Allocates Regenerative Flesh', 'value': 20388, 'oils': '3,6,3'},
#   {'string': 'Allocates Authority', 'value': 20397, 'oils': '3,5,9'},
#   {'string': 'Allocates Reprisal', 'value': 20414, 'oils': '1,7,7'},
#   {'string': 'Allocates Grit', 'value': 20416, 'oils': '9,6,5'},
#   {'string': 'Allocates For the Jugular', 'value': 20677, 'oils': '4,9,2'},
#   {'string': 'Allocates Catlike Agility', 'value': 20831, 'oils': '4,2,1'},
#   {'string': 'Allocates Blinding Strike', 'value': 20916, 'oils': '5,8,5'},
#   {'string': 'Allocates Fleshcrafting', 'value': 21164, 'oils': '10,3,8'},
#   {'string': 'Allocates Explosive Impact', 'value': 21206, 'oils': '3,6,8'},
#   {'string': 'Allocates Preemptive Strike', 'value': 21380, 'oils': '2,6,3'},
#   {'string': 'Allocates Breakage', 'value': 21453, 'oils': '8,5,3'},
#   {'string': 'Allocates Fervour', 'value': 21537, 'oils': '8,2,10'},
#   {'string': 'Allocates Impending Doom', 'value': 21748, 'oils': '5,10,1'},
#   {'string': 'Allocates Calibration', 'value': 21935, 'oils': '9,10,7'},
#   {'string': 'Allocates Irreparable', 'value': 22626, 'oils': '2,7,6'},
#   {'string': 'Allocates Tainted Strike', 'value': 22864, 'oils': '1,7,3'},
#   {'string': 'Allocates Vigilance', 'value': 22967, 'oils': '2,5,2'},
#   {'string': 'Allocates Holy Protector', 'value': 23078, 'oils': '6,7,9'},
#   {'string': 'Allocates Trick Shot', 'value': 23221, 'oils': '9,10,2'},
#   {'string': 'Allocates Initiative', 'value': 23227, 'oils': '3,1,5'},
#   {'string': 'Allocates Slippery Ice', 'value': 23362, 'oils': '7,6,3'},
#   {'string': 'Allocates Chilled to the Bone', 'value': 23427, 'oils': '9,7,7'},
#   {'string': 'Allocates Madness in the Bones',
#    'value': 23738,
#    'oils': '1,4,9'},
#   {'string': 'Allocates Alternating Current', 'value': 23764, 'oils': '1,1,9'},
#   {'string': 'Allocates Glazed Flesh', 'value': 23939, 'oils': '10,8,8'},
#   {'string': 'Allocates Adamant Recovery', 'value': 23940, 'oils': '10,5,1'},
#   {'string': 'Allocates Immortal Infamy', 'value': 24062, 'oils': '5,9,8'},
#   {'string': 'Allocates Mental Toughness', 'value': 24120, 'oils': '5,8,3'},
#   {'string': 'Allocates Time Manipulation', 'value': 24240, 'oils': '8,7,5'},
#   {'string': 'Allocates Hardened Wood', 'value': 24438, 'oils': '7,3,7'},
#   {'string': 'Allocates Direct Approach', 'value': 24483, 'oils': '6,4,4'},
#   {'string': 'Allocates Fulmination', 'value': 24630, 'oils': '9,9,3'},
#   {'string': 'Allocates Breath of Fire', 'value': 24655, 'oils': '8,1,10'},
#   {'string': 'Allocates Determined Precision',
#    'value': 24753,
#    'oils': '1,3,5'},
#   {'string': 'Allocates Beef', 'value': 25482, 'oils': '8,6,8'},
#   {'string': 'Allocates Overwhelm', 'value': 25513, 'oils': '7,8,5'},
#   {'string': 'Allocates Sand in the Eyes', 'value': 25619, 'oils': '7,7,7'},
#   {'string': 'Allocates Meat Recycling', 'value': 25620, 'oils': '4,7,2'},
#   {'string': 'Allocates Thrill of Battle', 'value': 25711, 'oils': '2,9,1'},
#   {'string': 'Allocates Tenfold Attacks', 'value': 25971, 'oils': '3,8,2'},
#   {'string': 'Allocates Bolstering Yell', 'value': 26070, 'oils': '9,6,4'},
#   {'string': 'Allocates Kite Runner', 'value': 26107, 'oils': '1,10,7'},
#   {'string': 'Allocates Electrifying Nature', 'value': 26291, 'oils': '5,3,4'},
#   {'string': 'Allocates Harsh Winter', 'value': 26331, 'oils': '8,7,1'},
#   {'string': 'Allocates Ancestral Artifice', 'value': 26339, 'oils': '9,9,9'},
#   {'string': 'Allocates Refocus', 'value': 26447, 'oils': '4,9,1'},
#   {'string': 'Allocates Cold Nature', 'value': 26518, 'oils': '5,8,2'},
#   {'string': 'Allocates Lust for Sacrifice', 'value': 27009, 'oils': '6,9,4'},
#   {'string': 'Allocates Mass Hysteria', 'value': 27108, 'oils': '6,6,5'},
#   {'string': 'Allocates The Power Within', 'value': 27176, 'oils': '5,4,9'},
#   {'string': 'Allocates Heavy Blade', 'value': 27290, 'oils': '2,3,9'},
#   {'string': 'Allocates Vulgar Methods', 'value': 27303, 'oils': '1,2,7'},
#   {'string': 'Allocates Aspiring Genius', 'value': 27388, 'oils': '9,3,3'},
#   {'string': 'Allocates Destructive Apparatus',
#    'value': 27417,
#    'oils': '5,1,7'},
#   {'string': 'Allocates Heavy Buffer', 'value': 27491, 'oils': '3,4,10'},
#   {'string': 'Allocates Touch the Arcane', 'value': 27626, 'oils': '7,10,9'},
#   {'string': 'Allocates Greatest Defence', 'value': 27687, 'oils': '9,8,6'},
#   {'string': 'Allocates General Electric', 'value': 27875, 'oils': '10,9,3'},
#   {'string': 'Allocates Polished Iron', 'value': 27950, 'oils': '4,2,7'},
#   {'string': 'Allocates Coming Calamity', 'value': 28044, 'oils': '6,10,9'},
#   {'string': 'Allocates Desensitisation', 'value': 28267, 'oils': '5,9,3'},
#   {'string': 'Allocates Pressure Points', 'value': 28329, 'oils': '2,7,1'},
#   {'string': 'Allocates Total Incineration', 'value': 28482, 'oils': '2,10,9'},
#   {'string': 'Allocates Devoted Protector', 'value': 28950, 'oils': '7,5,5'},
#   {'string': 'Allocates Way of the Wind', 'value': 28963, 'oils': '2,3,7'},
#   {'string': 'Allocates Pure Power', 'value': 28975, 'oils': '9,2,9'},
#   {'string': 'Allocates Honed Instincts', 'value': 28992, 'oils': '7,5,4'},
#   {'string': 'Allocates Sudden Infuriation', 'value': 29372, 'oils': '8,9,10'},
#   {'string': 'Allocates Cluster Bombs', 'value': 29514, 'oils': '9,10,6'},
#   {'string': 'Allocates First Approach', 'value': 29527, 'oils': '4,1,8'},
#   {'string': 'Allocates Guttural Roar', 'value': 29762, 'oils': '4,1,6'},
#   {'string': 'Allocates Master Fletching', 'value': 30341, 'oils': '8,7,6'},
#   {'string': 'Allocates Succour', 'value': 30392, 'oils': '6,7,2'},
#   {'string': 'Allocates High Alert', 'value': 30456, 'oils': '1,1,3'},
#   {'string': 'Allocates Dead can Dance', 'value': 30523, 'oils': '7,8,1'},
#   {'string': 'Allocates Inner Faith', 'value': 30562, 'oils': '5,3,10'},
#   {'string': 'Allocates Vile Wounds', 'value': 30695, 'oils': '4,7,9'},
#   {'string': 'Allocates Entropic Incarnation',
#    'value': 30720,
#    'oils': '9,9,5'},
#   {'string': 'Allocates Falcon Technique', 'value': 31172, 'oils': '9,9,7'},
#   {'string': 'Allocates Grip of Evil', 'value': 31175, 'oils': '10,7,1'},
#   {'string': 'Allocates Unexpected Finesse', 'value': 31189, 'oils': '7,3,10'},
#   {'string': 'Allocates Slow Burn', 'value': 31326, 'oils': '2,9,4'},
#   {'string': 'Allocates Primal Protection', 'value': 31364, 'oils': '2,3,4'},
#   {'string': 'Allocates Vocal Empowerment', 'value': 31373, 'oils': '10,10,7'},
#   {'string': 'Allocates Catalysis', 'value': 31433, 'oils': '10,10,4'},
#   {'string': 'Allocates Warding Fetish', 'value': 31925, 'oils': '8,9,5'},
#   {'string': 'Allocates Primal Growth', 'value': 32071, 'oils': '5,8,8'},
#   {'string': 'Allocates Rattling Ball', 'value': 32148, 'oils': '3,7,7'},
#   {'string': 'Allocates Frazzled', 'value': 32301, 'oils': '7,6,4'},
#   {'string': 'Allocates Swift Claw', 'value': 32353, 'oils': '9,8,7'},
#   {'string': 'Allocates Defiance', 'value': 32354, 'oils': '5,2,1'},
#   {'string': 'Allocates Sturdy Metal', 'value': 32416, 'oils': '4,3,6'},
#   {'string': 'Allocates Cut to the Bone', 'value': 32507, 'oils': '7,5,10'},
#   {'string': 'Allocates Flurry', 'value': 32664, 'oils': '8,9,2'},
#   {'string': 'Allocates Essence of the Mountain',
#    'value': 32683,
#    'oils': '7,1,9'},
#   {'string': 'Allocates Preservation', 'value': 32951, 'oils': '6,9,1'},
#   {'string': 'Allocates Back in Action', 'value': 33059, 'oils': '1,2,3'},
#   {'string': 'Allocates Effervescent', 'value': 33093, 'oils': '9,10,5'},
#   {'string': "Allocates Hunter's Talisman", 'value': 33099, 'oils': '4,4,4'},
#   {'string': 'Allocates Deep Wounds', 'value': 33216, 'oils': '6,7,4'},
#   {'string': 'Allocates Lord of Horrors', 'value': 33240, 'oils': '10,10,1'},
#   {'string': 'Allocates Full Salvo', 'value': 33887, 'oils': '1,10,3'},
#   {'string': 'Allocates Unstoppable Barrier', 'value': 33978, 'oils': '8,4,1'},
#   {'string': 'Allocates Crashing Wave', 'value': 34168, 'oils': '5,2,7'},
#   {'string': 'Allocates Flow State', 'value': 34233, 'oils': '7,2,5'},
#   {'string': 'Allocates Conservative Casting',
#    'value': 34300,
#    'oils': '6,6,1'},
#   {'string': 'Allocates Personal Touch', 'value': 34308, 'oils': '6,7,1'},
#   {'string': 'Allocates One with the River', 'value': 34316, 'oils': '2,4,10'},
#   {'string': 'Allocates Spectral Ward', 'value': 34324, 'oils': '5,8,9'},
#   {'string': 'Allocates Mass Rejuvenation', 'value': 34340, 'oils': '1,4,3'},
#   {'string': 'Allocates Spaghettification', 'value': 34473, 'oils': '10,7,8'},
#   {'string': 'Allocates Hallowed', 'value': 34531, 'oils': '7,6,6'},
#   {'string': 'Allocates In the Thick of It', 'value': 35028, 'oils': '6,7,3'},
#   {'string': 'Allocates Burnout', 'value': 35324, 'oils': '10,3,4'},
#   {'string': 'Allocates Investing Energies', 'value': 35369, 'oils': '1,1,5'},
#   {'string': 'Allocates Far Sighted', 'value': 35477, 'oils': '2,1,8'},
#   {'string': 'Allocates Turn the Clock Back', 'value': 35564, 'oils': '8,8,7'},
#   {'string': 'Allocates Near at Hand', 'value': 35581, 'oils': '4,10,4'},
#   {'string': 'Allocates Crushing Judgement', 'value': 35739, 'oils': '3,10,1'},
#   {'string': 'Allocates Reinvigoration', 'value': 35809, 'oils': '6,5,1'},
#   {'string': 'Allocates Thickened Arteries', 'value': 35849, 'oils': '5,2,3'},
#   {'string': 'Allocates Fortifying Blood', 'value': 35855, 'oils': '3,4,8'},
#   {'string': 'Allocates Admonisher', 'value': 35876, 'oils': '6,9,6'},
#   {'string': 'Allocates Heart Tissue', 'value': 35966, 'oils': '4,7,1'},
#   {'string': 'Allocates Blur', 'value': 35987, 'oils': '4,6,1'},
#   {'string': 'Allocates Serrated Edges', 'value': 36085, 'oils': '4,6,3'},
#   {'string': 'Allocates Practiced Signs', 'value': 36302, 'oils': '3,2,5'},
#   {'string': 'Allocates Cull the Hordes', 'value': 36341, 'oils': '7,2,9'},
#   {'string': 'Allocates Electrocution', 'value': 36364, 'oils': '4,9,3'},
#   {'string': 'Allocates Essence of the Storm',
#    'value': 36479,
#    'oils': '3,8,4'},
#   {'string': 'Allocates Vile Mending', 'value': 36507, 'oils': '3,8,8'},
#   {'string': 'Allocates Convalescence', 'value': 36623, 'oils': '6,9,3'},
#   {'string': 'Allocates Spiked Shield', 'value': 36808, 'oils': '8,9,8'},
#   {'string': 'Allocates Marked for Death', 'value': 36976, 'oils': '10,9,2'},
#   {'string': 'Allocates Shield Expertise', 'value': 37244, 'oils': '6,3,8'},
#   {'string': 'Allocates Two-Pronged Attack', 'value': 37266, 'oils': '1,8,2'},
#   {'string': 'Allocates Battle Trance', 'value': 37276, 'oils': '10,6,8'},
#   {'string': 'Allocates Staunching', 'value': 37408, 'oils': '5,7,6'},
#   {'string': 'Allocates Strong Links', 'value': 37458, 'oils': '2,6,5'},
#   {'string': 'Allocates Whirling Assault', 'value': 37514, 'oils': '5,6,3'},
#   {'string': 'Allocates Full Recovery', 'value': 37543, 'oils': '7,5,2'},
#   {'string': 'Allocates Devestating Devices', 'value': 37688, 'oils': '6,5,3'},
#   {'string': 'Allocates Manifold Method', 'value': 37742, 'oils': '4,4,8'},
#   {'string': 'Allocates Branching Bolts', 'value': 37806, 'oils': '9,6,1'},
#   {'string': 'Allocates Presence Present', 'value': 37872, 'oils': '1,8,10'},
#   {'string': 'Allocates Deafening Cries', 'value': 38053, 'oils': '6,2,4'},
#   {'string': 'Allocates Pliable Flesh', 'value': 38111, 'oils': '3,6,10'},
#   {'string': 'Allocates Stupefy', 'value': 38342, 'oils': '4,7,4'},
#   {'string': 'Allocates Apocalypse', 'value': 38398, 'oils': '9,4,3'},
#   {'string': 'Allocates Close Confines', 'value': 38479, 'oils': '1,4,1'},
#   {'string': 'Allocates Stormcharged', 'value': 38535, 'oils': '8,8,5'},
#   {'string': 'Allocates Heartstopping', 'value': 38537, 'oils': '1,7,4'},
#   {'string': 'Allocates Psychic Fragmentation',
#    'value': 38614,
#    'oils': '4,6,10'},
#   {'string': 'Allocates Escalating Toxins', 'value': 38628, 'oils': '7,10,6'},
#   {'string': 'Allocates Unerring Impact', 'value': 38888, 'oils': '3,6,1'},
#   {'string': 'Allocates Crystal Elixir', 'value': 38895, 'oils': '8,9,3'},
#   {'string': 'Allocates Finesse', 'value': 38969, 'oils': '8,9,6'},
#   {'string': 'Allocates Restless Dead', 'value': 38972, 'oils': '7,8,6'},
#   {'string': 'Allocates Exploit', 'value': 39050, 'oils': '6,5,10'},
#   {'string': 'Allocates Blood Rush', 'value': 39083, 'oils': '2,8,6'},
#   {'string': 'Allocates Breaking Blows', 'value': 39347, 'oils': '6,6,6'},
#   {'string': 'Allocates Struck Through', 'value': 39369, 'oils': '10,7,3'},
#   {'string': 'Allocates Ingenuity', 'value': 39567, 'oils': '1,10,9'},
#   {'string': 'Allocates Staggering Palm', 'value': 39881, 'oils': '2,10,7'},
#   {'string': 'Allocates Chronomancy', 'value': 39990, 'oils': '7,8,7'},
#   {'string': 'Allocates Drenched', 'value': 40073, 'oils': '10,9,1'},
#   {'string': 'Allocates Spiked Armour', 'value': 40117, 'oils': '7,2,6'},
#   {'string': 'Allocates Deep Trance', 'value': 40166, 'oils': '8,1,7'},
#   {'string': 'Allocates Taste for Blood', 'value': 40213, 'oils': '5,1,3'},
#   {'string': 'Allocates Frenetic', 'value': 40270, 'oils': '1,9,2'},
#   {'string': 'Allocates Resolution', 'value': 40325, 'oils': '5,6,5'},
#   {'string': 'Allocates Master of Hexes', 'value': 40345, 'oils': '9,8,9'},
#   {'string': 'Allocates Energise', 'value': 40399, 'oils': '10,2,4'},
#   {'string': 'Allocates Harmonic Generator', 'value': 40480, 'oils': '4,8,7'},
#   {'string': 'Allocates Sigil of Ice', 'value': 40803, 'oils': '9,6,2'},
#   {'string': 'Allocates Exposed to the Storm',
#    'value': 40990,
#    'oils': '5,10,7'},
#   {'string': 'Allocates Ricochet', 'value': 41210, 'oils': '1,6,6'},
#   {'string': 'Allocates Heavy Weaponry', 'value': 41512, 'oils': '4,6,5'},
#   {'string': 'Allocates Maiming Strike', 'value': 41580, 'oils': '7,10,1'},
#   {'string': 'Allocates Shatter Palm', 'value': 41811, 'oils': '3,7,4'},
#   {'string': 'Allocates Gravedigger', 'value': 41905, 'oils': '1,8,6'},
#   {'string': 'Allocates Glaciation', 'value': 41972, 'oils': '4,2,10'},
#   {'string': 'Allocates Deflection', 'value': 42036, 'oils': '3,8,9'},
#   {'string': 'Allocates Surging Currents', 'value': 42065, 'oils': '8,5,10'},
#   {'string': 'Allocates Essence Infusion', 'value': 42077, 'oils': '5,5,3'},
#   {'string': 'Allocates Blurred Motion', 'value': 42177, 'oils': '7,4,1'},
#   {'string': 'Allocates Split Shot', 'value': 42302, 'oils': '1,8,4'},
#   {'string': 'Allocates Blinding Flash', 'value': 42354, 'oils': '1,2,1'},
#   {'string': 'Allocates Overheating Blow', 'value': 42390, 'oils': '6,9,2'},
#   {'string': 'Allocates Clean Shot', 'value': 42781, 'oils': '7,1,3'},
#   {'string': 'Allocates Tides of Change', 'value': 42813, 'oils': '4,9,8'},
#   {'string': 'Allocates Ball and Chain', 'value': 42914, 'oils': '3,2,9'},
#   {'string': 'Allocates Low Tolerance', 'value': 42959, 'oils': '9,3,10'},
#   {'string': 'Allocates Cruel Methods', 'value': 42981, 'oils': '9,5,4'},
#   {'string': 'Allocates Acceleration', 'value': 43082, 'oils': '8,5,6'},
#   {'string': 'Allocates Electrotherapy', 'value': 43090, 'oils': '9,1,2'},
#   {'string': 'Allocates Stormbreaker', 'value': 43139, 'oils': '10,7,2'},
#   {'string': 'Allocates Exposed Wounds', 'value': 43383, 'oils': '5,4,3'},
#   {'string': 'Allocates Ancestral Reach', 'value': 43396, 'oils': '9,4,1'},
#   {'string': 'Allocates Emboldened Avatar', 'value': 43423, 'oils': '9,6,3'},
#   {'string': 'Allocates Crippling Toxins', 'value': 43677, 'oils': '5,10,5'},
#   {'string': 'Allocates Lasting Concoctions', 'value': 43695, 'oils': '7,6,7'},
#   {'string': 'Allocates Thornhide', 'value': 43711, 'oils': '1,3,8'},
#   {'string': 'Allocates Advanced Munitions', 'value': 43829, 'oils': '2,8,3'},
#   {'string': 'Allocates Fireproof', 'value': 43939, 'oils': '8,4,4'},
#   {'string': 'Allocates Casting Cascade', 'value': 44005, 'oils': '8,3,10'},
#   {'string': 'Allocates Enhanced Barrier', 'value': 44299, 'oils': '10,4,10'},
#   {'string': 'Allocates Coated Arms', 'value': 44330, 'oils': '8,3,4'},
#   {'string': 'Allocates Wither Away', 'value': 44373, 'oils': '2,2,10'},
#   {'string': 'Allocates Cautious Concoctions',
#    'value': 44527,
#    'oils': '6,4,6'},
#   {'string': 'Allocates Lightning Rod', 'value': 44566, 'oils': '9,10,10'},
#   {'string': 'Allocates Remorseless', 'value': 44605, 'oils': '3,6,2'},
#   {'string': 'Allocates Marked Agility', 'value': 44756, 'oils': '7,6,9'},
#   {'string': 'Allocates Distracting Presence',
#    'value': 44765,
#    'oils': '5,2,9'},
#   {'string': 'Allocates Feel no Pain', 'value': 44836, 'oils': '4,3,2'},
#   {'string': 'Allocates Self Mortification', 'value': 44917, 'oils': '1,5,5'},
#   {'string': 'Allocates Made to Last', 'value': 44952, 'oils': '9,8,2'},
#   {'string': 'Allocates Finishing Blows', 'value': 45013, 'oils': '7,2,1'},
#   {'string': 'Allocates Refills', 'value': 45244, 'oils': '3,1,10'},
#   {'string': 'Allocates Smash', 'value': 45363, 'oils': '5,5,1'},
#   {'string': 'Allocates Cross Strike', 'value': 45488, 'oils': '2,3,5'},
#   {'string': 'Allocates Lay Siege', 'value': 45599, 'oils': '8,5,8'},
#   {'string': 'Allocates Defensive Reflexes', 'value': 45612, 'oils': '3,1,1'},
#   {'string': 'Allocates Mind Eraser', 'value': 45632, 'oils': '8,1,4'},
#   {'string': 'Allocates Savouring', 'value': 45713, 'oils': '6,1,10'},
#   {'string': 'Allocates Sigil of Lightning', 'value': 46024, 'oils': '4,9,4'},
#   {'string': 'Allocates Voracious', 'value': 46060, 'oils': '3,10,9'},
#   {'string': 'Allocates Careful Assassin', 'value': 46197, 'oils': '9,5,3'},
#   {'string': 'Allocates Arcane Alchemy', 'value': 46224, 'oils': '5,3,3'},
#   {'string': 'Allocates Short Shot', 'value': 46296, 'oils': '9,2,5'},
#   {'string': 'Allocates Wide Barrier', 'value': 46384, 'oils': '5,10,10'},
#   {'string': 'Allocates Guts', 'value': 46499, 'oils': '9,1,1'},
#   {'string': 'Allocates Stance Breaker', 'value': 46565, 'oils': '1,2,2'},
#   {'string': 'Allocates Efficient Alchemy', 'value': 46692, 'oils': '8,1,2'},
#   {'string': 'Allocates Impair', 'value': 46696, 'oils': '5,9,6'},
#   {'string': 'Allocates Arcane Mixtures', 'value': 46972, 'oils': '4,4,2'},
#   {'string': 'Allocates Inescapable Cold', 'value': 47270, 'oils': '1,4,10'},
#   {'string': 'Allocates Goring', 'value': 47316, 'oils': '1,10,10'},
#   {'string': 'Allocates Colossal Weapon', 'value': 47363, 'oils': '8,3,1'},
#   {'string': 'Allocates Warding Potions', 'value': 47418, 'oils': '3,5,4'},
#   {'string': 'Allocates Stigmata', 'value': 47441, 'oils': '6,2,8'},
#   {'string': 'Allocates Overload', 'value': 47635, 'oils': '4,10,5'},
#   {'string': 'Allocates Quick-change Act', 'value': 47782, 'oils': '5,6,1'},
#   {'string': 'Allocates Devastation', 'value': 48006, 'oils': '1,1,7'},
#   {'string': 'Allocates Honourless', 'value': 48014, 'oils': '1,2,8'},
#   {'string': 'Allocates Forcewave', 'value': 48103, 'oils': '3,4,4'},
#   {'string': 'Allocates Step Like Mist', 'value': 48198, 'oils': '7,7,1'},
#   {'string': 'Allocates Quick Recovery', 'value': 48240, 'oils': '7,9,3'},
#   {'string': 'Allocates Hefty Unit', 'value': 48418, 'oils': '1,6,9'},
#   {'string': 'Allocates Bringer of Order', 'value': 48565, 'oils': '5,8,6'},
#   {'string': 'Allocates Exploit the Elements',
#    'value': 48581,
#    'oils': '3,8,10'},
#   {'string': 'Allocates Shattering', 'value': 48658, 'oils': '3,8,7'},
#   {'string': 'Allocates Taut Flesh', 'value': 48774, 'oils': '6,1,4'},
#   {'string': 'Allocates Altered Brain Chemistry',
#    'value': 48974,
#    'oils': '1,5,2'},
#   {'string': 'Allocates Fear of Death', 'value': 49088, 'oils': '5,4,2'},
#   {'string': 'Allocates Flow Like Water', 'value': 49220, 'oils': '3,2,7'},
#   {'string': 'Allocates Morning Star', 'value': 49370, 'oils': '5,3,9'},
#   {'string': 'Allocates Prolonged Fury', 'value': 49550, 'oils': '1,3,7'},
#   {'string': 'Allocates Deadly Flourish', 'value': 49618, 'oils': '5,1,2'},
#   {'string': 'Allocates Perfectly Placed Knife',
#    'value': 49661,
#    'oils': '8,4,10'},
#   {'string': 'Allocates Shattered Crystal', 'value': 49740, 'oils': '9,8,1'},
#   {'string': 'Allocates Spellblade', 'value': 49984, 'oils': '7,8,8'},
#   {'string': 'Allocates Reinforced Barrier', 'value': 50062, 'oils': '7,3,5'},
#   {'string': 'Allocates Aftershocks', 'value': 50253, 'oils': '7,2,3'},
#   {'string': 'Allocates Twinned Tethers', 'value': 50389, 'oils': '2,5,6'},
#   {'string': 'Allocates Zone of Control', 'value': 50485, 'oils': '10,10,5'},
#   {'string': 'Allocates Barbaric Strength', 'value': 50562, 'oils': '2,7,5'},
#   {'string': 'Allocates Hard to Kill', 'value': 50609, 'oils': '2,3,2'},
#   {'string': 'Allocates Coursing Energy', 'value': 50687, 'oils': '5,6,4'},
#   {'string': 'Allocates Careful Aim', 'value': 50795, 'oils': '2,2,4'},
#   {'string': 'Allocates Spirit Bond', 'value': 51105, 'oils': '3,1,8'},
#   {'string': 'Allocates Pile On', 'value': 51129, 'oils': '10,1,1'},
#   {'string': 'Allocates Soul Bloom', 'value': 51169, 'oils': '7,1,10'},
#   {'string': 'Allocates Raw Power', 'value': 51184, 'oils': '3,5,7'},
#   {'string': 'Allocates Wasting', 'value': 51213, 'oils': '2,8,7'},
#   {'string': 'Allocates Path of Flame', 'value': 51335, 'oils': '9,8,3'},
#   {'string': 'Allocates Unimpeded', 'value': 51394, 'oils': '10,5,10'},
#   {'string': 'Allocates Leather Bound Gauntlets',
#    'value': 51446,
#    'oils': '3,9,1'},
#   {'string': 'Allocates Waters of Life', 'value': 51509, 'oils': '3,8,6'},
#   {'string': 'Allocates Unsight', 'value': 51602, 'oils': '9,6,7'},
#   {'string': 'Allocates Freedom of Movement', 'value': 51606, 'oils': '3,3,5'},
#   {'string': 'Allocates Enhanced Reflexes', 'value': 51707, 'oils': '8,1,5'},
#   {'string': 'Allocates Ancestral Conduits', 'value': 51820, 'oils': '7,9,9'},
#   {'string': 'Allocates Immortal Thirst', 'value': 51871, 'oils': '2,9,2'},
#   {'string': 'Allocates Lucidity', 'value': 51891, 'oils': '5,6,9'},
#   {'string': 'Allocates Invocated Efficiency',
#    'value': 51934,
#    'oils': '10,5,4'},
#   {'string': 'Allocates Event Horizon', 'value': 52191, 'oils': '7,10,2'},
#   {'string': 'Allocates Overexposure', 'value': 52199, 'oils': '9,10,3'},
#   {'string': 'Allocates Carved Earth', 'value': 52348, 'oils': '9,9,1'},
#   {'string': 'Allocates Singular Purpose', 'value': 52392, 'oils': '6,5,8'},
#   {'string': 'Allocates Feral Force', 'value': 52618, 'oils': '8,9,4'},
#   {'string': 'Allocates Hale Traveller', 'value': 52803, 'oils': '5,6,6'},
#   {'string': 'Allocates Quick Response', 'value': 52971, 'oils': '5,6,8'},
#   {'string': 'Allocates Immolation', 'value': 53030, 'oils': '1,7,6'},
#   {'string': 'Allocates Sharp Sight', 'value': 53150, 'oils': '2,6,1'},
#   {'string': 'Allocates Burn Away', 'value': 53294, 'oils': '8,6,6'},
#   {'string': 'Allocates Shattering Blow', 'value': 53527, 'oils': '8,2,2'},
#   {'string': 'Allocates Towering Shield', 'value': 53823, 'oils': '1,7,2'},
#   {'string': 'Allocates Backup Plan', 'value': 53853, 'oils': '3,3,1'},
#   {'string': 'Allocates Unbreaking', 'value': 53921, 'oils': '4,5,4'},
#   {'string': 'Allocates Briny Carapace', 'value': 53935, 'oils': '2,1,4'},
#   {'string': 'Allocates Shimmering', 'value': 53941, 'oils': '5,5,9'},
#   {'string': 'Allocates Smoke Inhalation', 'value': 54148, 'oils': '10,5,8'},
#   {'string': 'Allocates Hindered Capabilities',
#    'value': 54805,
#    'oils': '9,3,5'},
#   {'string': 'Allocates Firestarter', 'value': 54911, 'oils': '3,10,2'},
#   {'string': 'Allocates Vengeful Fury', 'value': 54937, 'oils': '9,1,7'},
#   {'string': 'Allocates Bloodletting', 'value': 54990, 'oils': '8,9,1'},
#   {'string': 'Allocates Protraction', 'value': 54998, 'oils': '7,6,2'},
#   {'string': 'Allocates Shrapnel', 'value': 55060, 'oils': '2,2,6'},
#   {'string': 'Allocates Pure Chaos', 'value': 55149, 'oils': '5,10,2'},
#   {'string': 'Allocates Relentless Fallen', 'value': 55180, 'oils': '7,8,10'},
#   {'string': 'Allocates Subterfuge Mask', 'value': 55193, 'oils': '1,9,4'},
#   {'string': 'Allocates Forthcoming', 'value': 55568, 'oils': '7,3,9'},
#   {'string': 'Allocates Electric Amplification',
#    'value': 55708,
#    'oils': '10,8,6'},
#   {'string': 'Allocates Exposed to the Cosmos',
#    'value': 55835,
#    'oils': '10,8,4'},
#   {'string': 'Allocates Ice Walls', 'value': 55847, 'oils': '8,4,6'},
#   {'string': 'Allocates Lingering Horror', 'value': 56063, 'oils': '10,6,6'},
#   {'string': 'Allocates Throatseeker', 'value': 56265, 'oils': '3,5,10'},
#   {'string': 'Allocates Silent Shiv', 'value': 56366, 'oils': '9,3,7'},
#   {'string': 'Allocates Killer Instinct', 'value': 56453, 'oils': '3,4,3'},
#   {'string': 'Allocates Desperate Times', 'value': 56616, 'oils': '7,6,1'},
#   {'string': 'Allocates Cooked', 'value': 56776, 'oils': '9,1,5'},
#   {'string': 'Allocates Parrying Motion', 'value': 56806, 'oils': '1,8,1'},
#   {'string': 'Allocates Thicket Warding', 'value': 56893, 'oils': '4,8,4'},
#   {'string': 'Allocates Battle-hardened', 'value': 56910, 'oils': '3,2,4'},
#   {'string': 'Allocates Heavy Contact', 'value': 56997, 'oils': '1,5,7'},
#   {'string': 'Allocates Locked On', 'value': 56999, 'oils': '7,6,5'},
#   {'string': 'Allocates Polymathy', 'value': 57047, 'oils': '10,9,4'},
#   {'string': 'Allocates Spirit Bonds', 'value': 57097, 'oils': '3,1,9'},
#   {'string': 'Allocates Infused Flesh', 'value': 57110, 'oils': '3,5,5'},
#   {'string': 'Allocates Doomsayer', 'value': 57190, 'oils': '4,2,6'},
#   {'string': 'Allocates Critical Exploit', 'value': 57204, 'oils': '5,4,1'},
#   {'string': 'Allocates In Your Face', 'value': 57379, 'oils': '8,3,5'},
#   {'string': 'Allocates Overwhelming Strike', 'value': 57388, 'oils': '7,5,6'},
#   {'string': 'Allocates Hunker Down', 'value': 57471, 'oils': '7,7,4'},
#   {'string': 'Allocates Clear Space', 'value': 57805, 'oils': '4,2,2'},
#   {'string': 'Allocates Sturdy Mind', 'value': 57967, 'oils': '10,5,2'},
#   {'string': 'Allocates All Natural', 'value': 58016, 'oils': '8,8,3'},
#   {'string': 'Allocates Lasting Incantations',
#    'value': 58096,
#    'oils': '10,3,6'},
#   {'string': 'Allocates Blood Tearing', 'value': 58183, 'oils': '7,10,3'},
#   {'string': 'Allocates Proficiency', 'value': 58397, 'oils': '8,2,4'},
#   {'string': 'Allocates Pocket Sand', 'value': 58426, 'oils': '4,2,4'},
#   {'string': 'Allocates Grenadier', 'value': 58714, 'oils': '4,8,10'},
#   {'string': 'Allocates Dispatch Foes', 'value': 58939, 'oils': '5,5,4'},
#   {'string': 'Allocates Hold Focus', 'value': 59047, 'oils': '5,10,4'},
#   {'string': 'Allocates Potent Concoctions', 'value': 59142, 'oils': '6,1,2'},
#   {'string': 'Allocates Fated End', 'value': 59214, 'oils': '6,10,7'},
#   {'string': 'Allocates Ripping Blade', 'value': 59263, 'oils': '4,5,3'},
#   {'string': 'Allocates Lucky Rabbit Foot', 'value': 59303, 'oils': '10,6,1'},
#   {'string': 'Allocates Necrotised Flesh', 'value': 59541, 'oils': '8,2,8'},
#   {'string': 'Allocates Heavy Armour', 'value': 59589, 'oils': '7,8,3'},
#   {'string': 'Allocates Covering Ward', 'value': 59596, 'oils': '4,7,3'},
#   {'string': 'Allocates Open Mind', 'value': 59636, 'oils': '2,2,1'},
#   {'string': 'Allocates Beastial Skin', 'value': 59720, 'oils': '3,6,5'},
#   {'string': 'Allocates Reverberating Impact',
#    'value': 59767,
#    'oils': '5,4,7'},
#   {'string': 'Allocates Falcon Dive', 'value': 60034, 'oils': '10,4,4'},
#   {'string': 'Allocates Pin and Run', 'value': 60083, 'oils': '6,7,6'},
#   {'string': 'Allocates Stylebender', 'value': 60138, 'oils': '3,4,9'},
#   {'string': 'Allocates Roil', 'value': 60269, 'oils': '6,3,1'},
#   {'string': 'Allocates Perfect Opportunity', 'value': 60404, 'oils': '1,9,9'},
#   {'string': 'Allocates Fan the Flames', 'value': 60464, 'oils': '9,4,7'},
#   {'string': 'Allocates Echoing Flames', 'value': 60692, 'oils': '2,9,6'},
#   {'string': 'Allocates Feathered Fletching',
#    'value': 60764,
#    'oils': '10,9,9'},
#   {'string': 'Allocates Crystalline Flesh', 'value': 61026, 'oils': '7,4,9'},
#   {'string': 'Allocates Mana Blessing', 'value': 61027, 'oils': '2,7,2'},
#   {'string': 'Allocates Roll and Strike', 'value': 61112, 'oils': '2,4,6'},
#   {'string': 'Allocates Breath of Lightning',
#    'value': 61338,
#    'oils': '6,4,10'},
#   {'string': 'Allocates Equilibrium', 'value': 61404, 'oils': '8,9,7'},
#   {'string': 'Allocates Anticipation', 'value': 61444, 'oils': '8,5,7'},
#   {'string': 'Allocates Austerity Measures', 'value': 61493, 'oils': '4,5,7'},
#   {'string': 'Allocates True Strike', 'value': 61601, 'oils': '1,2,6'},
#   {'string': 'Allocates Sharpened Claw', 'value': 61703, 'oils': '1,3,3'},
#   {'string': 'Allocates Lasting Toxins', 'value': 61741, 'oils': '7,10,5'},
#   {'string': 'Allocates Storm Surge', 'value': 61921, 'oils': '5,10,3'},
#   {'string': 'Allocates Backstabbing', 'value': 62001, 'oils': '5,1,10'},
#   {'string': 'Allocates Prism Guard', 'value': 62034, 'oils': '10,10,9'},
#   {'string': 'Allocates Rattled', 'value': 62185, 'oils': '3,8,1'},
#   {'string': 'Allocates Patient Barrier', 'value': 62230, 'oils': '9,10,8'},
#   {'string': 'Allocates Incendiary', 'value': 62310, 'oils': '10,6,2'},
#   {'string': 'Allocates Enraged Reaver', 'value': 62439, 'oils': '10,10,8'},
#   {'string': 'Allocates Ancestral Unity', 'value': 62609, 'oils': '9,8,5'},
#   {'string': "Allocates Titan's Determination",
#    'value': 62732,
#    'oils': '1,4,4'},
#   {'string': 'Allocates Woodland Aspect', 'value': 62803, 'oils': '9,2,10'},
#   {'string': 'Allocates Living Death', 'value': 62887, 'oils': '3,9,6'},
#   {'string': 'Allocates Mindful Awareness', 'value': 62984, 'oils': '4,5,9'},
#   {'string': 'Allocates Sigil of Fire', 'value': 63037, 'oils': '9,2,1'},
#   {'string': 'Allocates Mystic Stance', 'value': 63064, 'oils': '8,3,2'},
#   {'string': 'Allocates Dark Entries', 'value': 63074, 'oils': '7,10,10'},
#   {'string': 'Allocates Savagery', 'value': 63255, 'oils': '9,8,4'},
#   {'string': 'Allocates Leeching Toxins', 'value': 63431, 'oils': '3,9,9'},
#   {'string': 'Allocates Cranial Impact', 'value': 63451, 'oils': '3,4,6'},
#   {'string': 'Allocates Thunderstruck', 'value': 63585, 'oils': '7,4,4'},
#   {'string': 'Allocates Clever Construction', 'value': 63659, 'oils': '6,2,7'},
#   {'string': 'Allocates Stacking Toxins', 'value': 63759, 'oils': '10,6,4'},
#   {'string': 'Allocates Marked for Sickness',
#    'value': 63830,
#    'oils': '2,6,10'},
#   {'string': 'Allocates Deft Recovery', 'value': 63981, 'oils': '5,1,1'},
#   {'string': 'Allocates Path of Storms', 'value': 64046, 'oils': '8,8,1'},
#   {'string': 'Allocates Instant Reload', 'value': 64119, 'oils': '8,2,9'},
#   {'string': 'Allocates Battle Fever', 'value': 64240, 'oils': '6,2,10'},
#   {'string': 'Allocates Bolstering Presence', 'value': 64299, 'oils': '7,5,9'},
#   {'string': "Allocates Defender's Resolve", 'value': 64327, 'oils': '2,4,3'},
#   {'string': 'Allocates Impact Force', 'value': 64443, 'oils': '8,1,8'},
#   {'string': 'Allocates Unbound Forces', 'value': 64543, 'oils': '6,5,2'},
#   {'string': 'Allocates Flashy Deflection', 'value': 64851, 'oils': '3,2,3'},
#   {'string': 'Allocates Intense Flames', 'value': 65016, 'oils': '2,9,8'},
#   {'string': 'Allocates Impenetrable Shell', 'value': 65023, 'oils': '4,4,1'},
#   {'string': 'Allocates Titanic', 'value': 65160, 'oils': '7,4,2'},
#   {'string': 'Allocates Viciousness', 'value': 65193, 'oils': '6,3,4'},
#   {'string': 'Allocates Overflowing Power', 'value': 65204, 'oils': '10,5,3'},
#   {'string': 'Allocates Smooth Buckler', 'value': 65265, 'oils': '2,5,3'},
#   {'string': 'Allocates Repeating Explosives',
#    'value': 65468,
#    'oils': '9,7,10'}]}
